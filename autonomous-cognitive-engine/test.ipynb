# %%
import langgraph
print("All set 🚀")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import langgraph
#       2 print("All set 🚀")
#
# ModuleNotFoundError: No module named 'langgraph'

# %%
import langgraph
print("All set 🚀")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import langgraph
#       2 print("All set 🚀")
#
# ModuleNotFoundError: No module named 'langgraph'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\sampa\autonomous-cognitive-engine\autonomous-cognitive-engine\.venv\Scripts\python.exe

# %%
import langgraph
print("All set 🚀")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import langgraph
#       2 print("All set 🚀")
#
# ModuleNotFoundError: No module named 'langgraph'
